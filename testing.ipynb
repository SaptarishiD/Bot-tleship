# %%
import matplotlib.pyplot as plt

# %%
from bot_random import RandomBot
from bot_humanlike import HumanLikeBot
from mcts_bot import MCTSBot
from helper_functions import test_bot

# %%
total_moves, mean, median, max_, min_, std, avg_hits_at_move, avg_moves_for_hit = test_bot(Bot=RandomBot)
print(f"RandomBot: mean={mean}, median={median}, max={max_}, min={min_}, std={std}")
# Out:
# ...
# 100%|██████████| 100/100 [00:00<00:00, 108.25it/s]
# [562, 1097, 1726, 2307, 2834, 3367, 3907, 4481, 5036, 5552, 6117, 6756, 7355, 7904, 8429, 8986, 9592]
# RandomBot: mean=95.92, median=97.0, max=100, min=74, std=4.478124607466836

# %%
plt.plot(avg_hits_at_move)

# %%
plt.plot(avg_moves_for_hit)

# %%
total_moves, mean, median, max_, min_, std, avg_hits_at_move, avg_moves_for_hit = test_bot(Bot=MCTSBot)
# Out:
# ...
# 100%|██████████| 100/100 [24:45<00:00, 14.85s/it]
# [494, 847, 1169, 1472, 1831, 2161, 2499, 2852, 3128, 3408, 3828, 4179, 4755, 5333, 5876, 6643, 7529]

# %%
plt.plot(avg_hits_at_move)

# %%
plt.plot(avg_moves_for_hit)

# %%
print(f"MCTSBot: mean={mean}, median={median}, max={max_}, min={min_}, std={std}")
# Out:
# MCTSBot: mean=75.29, median=73.0, max=100, min=41, std=16.788862379565803
