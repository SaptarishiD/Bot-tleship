# %%
import gymnasium as gym
from gymnasium.envs.registration import register
from ppo_env import BattleshipEnv

register(
    id="BattleshipEnvSD-v0",
    entry_point="BattleshipEnv",  # Replace with the actual module path
    kwargs={"board_height": 10, "board_width" : 10, "ships": [2, 3, 3, 4, 5]},
)
# Out:
# /Users/user/Documents_stuff/Ashoka/monsoon24-courses/AI/project/bot-venv/lib/python3.9/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment BattleshipEnvSD-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
gym.pprint_registry()
# Out:
# ===== classic_control =====
# Acrobot-v1                        CartPole-v0                       CartPole-v1
# MountainCar-v0                    MountainCarContinuous-v0          Pendulum-v1
# ===== phys2d =====
# phys2d/CartPole-v0                phys2d/CartPole-v1                phys2d/Pendulum-v0
# ===== box2d =====
# BipedalWalker-v3                  BipedalWalkerHardcore-v3          CarRacing-v2
# LunarLander-v2                    LunarLanderContinuous-v2
# ===== toy_text =====
# Blackjack-v1                      CliffWalking-v0                   FrozenLake-v1
# FrozenLake8x8-v1                  Taxi-v3
# ===== tabular =====
# tabular/Blackjack-v0              tabular/CliffWalking-v0
# ===== mujoco =====
# Ant-v2                            Ant-v3                            Ant-v4
# HalfCheetah-v2                    HalfCheetah-v3                    HalfCheetah-v4
# Hopper-v2                         Hopper-v3                         Hopper-v4
# ...

# %%
env = gym.make('env_init:BattleshipEnvSD-v0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 env = gym.make("env_init:BattleshipEnvSD-v0")
#
# File ~/Documents_stuff/Ashoka/monsoon24-courses/AI/project/bot-venv/lib/python3.9/site-packages/gymnasium/envs/registration.py:756, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     753     env_creator = env_spec.entry_point
#     754 else:
#     755     # Assume it's a string
# --> 756     env_creator = load_env_creator(env_spec.entry_point)
#     758 # Determine if to use the rendering
#     759 render_modes: list[str] | None = None
#
# File ~/Documents_stuff/Ashoka/monsoon24-courses/AI/project/bot-venv/lib/python3.9/site-packages/gymnasium/envs/registration.py:544, in load_env_creator(name)
#     535 def load_env_creator(name: str) -> EnvCreator | VectorEnvCreator:
# ...
