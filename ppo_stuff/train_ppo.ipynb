# %%
import os
import time
import numpy as np
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from gymnasium.envs.registration import register
from ppo_env.ppo import BattleshipEnv  # Assuming your BattleshipEnv is saved as battleship_env.py

import pandas as pd
import hvplot.pandas
from tqdm import tqdm

# Register the custom Battleship environment
register(
    id='BattleshipEnvSD-v0',
    entry_point='ppo_env.ppo:BattleshipEnv',  # Module path to the BattleshipEnv class
    kwargs={"board_size": 10, "ships": [2, 3, 3, 4, 5]},
    # max_episode_steps=100,  # Adjust based on game rules or preferences
)

# Create a directory for logging
timestr = time.strftime("%Y%m%d-%H%M%S")
log_dir = f"tmp/{timestr}/"
os.makedirs(log_dir, exist_ok=True)

# Initialize the environment and wrap it with Monitor for logging
env = gym.make("BattleshipEnvSD-v0")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='dff95b81-1441-435f-b09f-4fb38aa4989f'>
#   <div id="fbbbf346-6148-4f9b-a61e-2f4dd21c1e56" data-root-id="dff95b81-1441-435f-b09f-4fb38aa4989f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"db2270eb-d3dc-4d2c-bf01-c9c0b2ef4146":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"dff95b81-1441-435f-b09f-4fb38aa4989f"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"f5a9f682-3742-433d-b839-36bac79d0ab2","attributes":{"plot_id":"dff95b81-1441-435f-b09f-4fb38aa4989f","comm_id":"1416e80d310244a887f8e78ec644c9e8","client_comm_id":"0350e594c1cc4b6aa05bf37014b71560"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"db2270eb-d3dc-4d2c-bf01-c9c0b2ef4146","roots":{"dff95b81-1441-435f-b09f-4fb38aa4989f":"fbbbf346-6148-4f9b-a61e-2f4dd21c1e56"},"root_ids":["dff95b81-1441-435f-b09f-4fb38aa4989f"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# /Users/user/Documents_stuff/Ashoka/monsoon24-courses/AI/project/bot-venv/lib/python3.9/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment BattleshipEnvSD-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
env = Monitor(env, log_dir)

# Use DummyVecEnv to enable vectorized environments (needed for stable-baselines3)
vec_env = DummyVecEnv([lambda: env])

# Initialize the PPO model
model = PPO("MlpPolicy", vec_env, verbose=1)

# Train the model
model.learn(total_timesteps=100000)

# Save the trained model
model_save_path = f"models/{timestr}-ppo-battleship"
os.makedirs("models", exist_ok=True)
model.save(model_save_path)
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 349      |
# |    ep_rew_mean     | -242     |
# | time/              |          |
# |    fps             | 3126     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 388           |
# |    ep_rew_mean          | -281          |
# | time/                   |               |
# |    fps                  | 2318          |
# |    iterations           | 2             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.018551514   |
# |    clip_fraction        | 0.159         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.6          |
# |    explained_variance   | -0.0004581213 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.52          |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.0554       |
# |    value_loss           | 37.6          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 398         |
# |    ep_rew_mean          | -292        |
# | time/                   |             |
# |    fps                  | 1871        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012642389 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.36594933  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0313     |
# |    value_loss           | 36.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 365         |
# |    ep_rew_mean          | -261        |
# | time/                   |             |
# |    fps                  | 1637        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011724616 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.4676968   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0309     |
# |    value_loss           | 43          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 332         |
# |    ep_rew_mean          | -229        |
# | time/                   |             |
# |    fps                  | 1418        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015907986 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.44594622  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0567     |
# |    value_loss           | 27          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -232        |
# | time/                   |             |
# |    fps                  | 1368        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013863751 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.58       |
# |    explained_variance   | 0.37154675  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.77        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0531     |
# |    value_loss           | 26.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | -244         |
# | time/                   |              |
# |    fps                  | 1367         |
# |    iterations           | 7            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0142804105 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.58        |
# |    explained_variance   | 0.47362018   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.05         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0457      |
# |    value_loss           | 29.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 348         |
# |    ep_rew_mean          | -244        |
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015727513 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.58       |
# |    explained_variance   | 0.6442921   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.3        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 31.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 343         |
# |    ep_rew_mean          | -239        |
# | time/                   |             |
# |    fps                  | 1431        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012412626 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.58       |
# |    explained_variance   | 0.56857324  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 31          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 340         |
# |    ep_rew_mean          | -237        |
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 10          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013036868 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.57       |
# |    explained_variance   | 0.41420358  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.51        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.044      |
# |    value_loss           | 23          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 347         |
# |    ep_rew_mean          | -243        |
# | time/                   |             |
# |    fps                  | 1461        |
# |    iterations           | 11          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013139767 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.57       |
# |    explained_variance   | 0.41183197  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.9         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.045      |
# |    value_loss           | 29.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 345          |
# |    ep_rew_mean          | -242         |
# | time/                   |              |
# |    fps                  | 1476         |
# |    iterations           | 12           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0139206145 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.55        |
# |    explained_variance   | 0.47479612   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.3         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.041       |
# |    value_loss           | 26.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 349        |
# |    ep_rew_mean          | -245       |
# | time/                   |            |
# |    fps                  | 1493       |
# |    iterations           | 13         |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01426164 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.55      |
# |    explained_variance   | 0.34934926 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.5       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0431    |
# |    value_loss           | 25.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 349         |
# |    ep_rew_mean          | -245        |
# | time/                   |             |
# |    fps                  | 1505        |
# |    iterations           | 14          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015655885 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.60508287  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.99        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.044      |
# |    value_loss           | 25.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 353         |
# |    ep_rew_mean          | -249        |
# | time/                   |             |
# |    fps                  | 1514        |
# |    iterations           | 15          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.016939389 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.6546321   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.2         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 20.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 357        |
# |    ep_rew_mean          | -253       |
# | time/                   |            |
# |    fps                  | 1522       |
# |    iterations           | 16         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01667735 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.53      |
# |    explained_variance   | 0.44904447 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 29         |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0492    |
# |    value_loss           | 33.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 358         |
# |    ep_rew_mean          | -254        |
# | time/                   |             |
# |    fps                  | 1534        |
# |    iterations           | 17          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015628463 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.34599984  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.06        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0413     |
# |    value_loss           | 20.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -256        |
# | time/                   |             |
# |    fps                  | 1545        |
# |    iterations           | 18          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013306737 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | 0.5537179   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0443     |
# |    value_loss           | 28.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 358          |
# |    ep_rew_mean          | -254         |
# | time/                   |              |
# |    fps                  | 1554         |
# |    iterations           | 19           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0147436075 |
# |    clip_fraction        | 0.152        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.54        |
# |    explained_variance   | 0.62753963   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.9         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0462      |
# |    value_loss           | 23.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 355         |
# |    ep_rew_mean          | -251        |
# | time/                   |             |
# |    fps                  | 1556        |
# |    iterations           | 20          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.017276786 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.52       |
# |    explained_variance   | 0.6314726   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 22.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 356         |
# |    ep_rew_mean          | -252        |
# | time/                   |             |
# |    fps                  | 1556        |
# |    iterations           | 21          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013533313 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.52       |
# |    explained_variance   | 0.32961303  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.72        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 21.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 359         |
# |    ep_rew_mean          | -255        |
# | time/                   |             |
# |    fps                  | 1557        |
# |    iterations           | 22          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.014522402 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.52       |
# |    explained_variance   | 0.5858935   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.81        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0434     |
# |    value_loss           | 26.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 374         |
# |    ep_rew_mean          | -269        |
# | time/                   |             |
# |    fps                  | 1565        |
# |    iterations           | 23          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.031906024 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 0.04106623  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.056      |
# |    value_loss           | 14.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 378         |
# |    ep_rew_mean          | -274        |
# | time/                   |             |
# |    fps                  | 1573        |
# |    iterations           | 24          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.016210077 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | 0.40739948  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.14        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0441     |
# |    value_loss           | 23.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 374         |
# |    ep_rew_mean          | -270        |
# | time/                   |             |
# |    fps                  | 1579        |
# |    iterations           | 25          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012561752 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.5029385   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0405     |
# |    value_loss           | 27.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 377         |
# |    ep_rew_mean          | -273        |
# | time/                   |             |
# |    fps                  | 1586        |
# |    iterations           | 26          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.015188493 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 0.5956321   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.72        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0458     |
# |    value_loss           | 13.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 379        |
# |    ep_rew_mean          | -275       |
# | time/                   |            |
# |    fps                  | 1589       |
# |    iterations           | 27         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01478751 |
# |    clip_fraction        | 0.165      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.51      |
# |    explained_variance   | 0.63812566 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.06       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0434    |
# |    value_loss           | 22.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 380         |
# |    ep_rew_mean          | -276        |
# | time/                   |             |
# |    fps                  | 1595        |
# |    iterations           | 28          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.014454086 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.5        |
# |    explained_variance   | 0.6084669   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0451     |
# |    value_loss           | 22.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 392         |
# |    ep_rew_mean          | -288        |
# | time/                   |             |
# |    fps                  | 1598        |
# |    iterations           | 29          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.016684476 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.5        |
# |    explained_variance   | 0.27867144  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.22        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 16.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 382        |
# |    ep_rew_mean          | -279       |
# | time/                   |            |
# |    fps                  | 1603       |
# |    iterations           | 30         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.01849192 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.46      |
# |    explained_variance   | 0.66257906 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.83       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.049     |
# |    value_loss           | 21.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 387        |
# |    ep_rew_mean          | -283       |
# | time/                   |            |
# |    fps                  | 1606       |
# |    iterations           | 31         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.0164708  |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.51      |
# |    explained_variance   | 0.45283532 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.51       |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0482    |
# |    value_loss           | 21.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 390        |
# |    ep_rew_mean          | -286       |
# | time/                   |            |
# |    fps                  | 1611       |
# |    iterations           | 32         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.02028934 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.48      |
# |    explained_variance   | 0.18086153 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.09       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0493    |
# |    value_loss           | 13.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 395         |
# |    ep_rew_mean          | -291        |
# | time/                   |             |
# |    fps                  | 1615        |
# |    iterations           | 33          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.017900445 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 0.52766824  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.02        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0453     |
# |    value_loss           | 18.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 404         |
# |    ep_rew_mean          | -300        |
# | time/                   |             |
# |    fps                  | 1619        |
# |    iterations           | 34          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.018647283 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 0.22577089  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.26        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0434     |
# |    value_loss           | 15.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 409         |
# |    ep_rew_mean          | -305        |
# | time/                   |             |
# |    fps                  | 1623        |
# |    iterations           | 35          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.017667253 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | 0.67725027  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.2        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0414     |
# |    value_loss           | 16.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 412         |
# |    ep_rew_mean          | -308        |
# | time/                   |             |
# |    fps                  | 1625        |
# |    iterations           | 36          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.016471269 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | 0.49848711  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.56        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 17.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 421         |
# |    ep_rew_mean          | -317        |
# | time/                   |             |
# |    fps                  | 1627        |
# |    iterations           | 37          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.016236618 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | 0.42273635  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.72        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0414     |
# |    value_loss           | 21.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 429         |
# |    ep_rew_mean          | -325        |
# | time/                   |             |
# |    fps                  | 1612        |
# |    iterations           | 38          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.029227654 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | 0.35284823  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.31        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0407     |
# |    value_loss           | 11.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 437         |
# |    ep_rew_mean          | -333        |
# | time/                   |             |
# |    fps                  | 1593        |
# |    iterations           | 39          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.017316157 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 0.73532283  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.1         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0456     |
# |    value_loss           | 23.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 438         |
# |    ep_rew_mean          | -334        |
# | time/                   |             |
# |    fps                  | 1593        |
# |    iterations           | 40          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.018253528 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | 0.3701595   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.38        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0422     |
# |    value_loss           | 12.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 444         |
# |    ep_rew_mean          | -340        |
# | time/                   |             |
# |    fps                  | 1591        |
# |    iterations           | 41          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.017666573 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | 0.533373    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.19        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 18.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 454         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 1587        |
# |    iterations           | 42          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.026038144 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | 0.56267524  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.23        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0404     |
# |    value_loss           | 13.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 463         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 1583        |
# |    iterations           | 43          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.016275106 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.44       |
# |    explained_variance   | 0.32628775  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.67        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0453     |
# |    value_loss           | 21.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 1586        |
# |    iterations           | 44          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.018244587 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | 0.6618103   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.03        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0412     |
# |    value_loss           | 16.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 1589        |
# |    iterations           | 45          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.014646633 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 0.54071784  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.12        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0431     |
# |    value_loss           | 19          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 478         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 1592        |
# |    iterations           | 46          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.018176556 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 0.76670635  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0425     |
# |    value_loss           | 14.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 489        |
# |    ep_rew_mean          | -384       |
# | time/                   |            |
# |    fps                  | 1595       |
# |    iterations           | 47         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.03761342 |
# |    clip_fraction        | 0.391      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.4       |
# |    explained_variance   | 0.79395396 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.6        |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0312    |
# |    value_loss           | 13         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 495         |
# |    ep_rew_mean          | -390        |
# | time/                   |             |
# |    fps                  | 1598        |
# |    iterations           | 48          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.017868787 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 0.74885064  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.55        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 20.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -396        |
# | time/                   |             |
# |    fps                  | 1600        |
# |    iterations           | 49          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.016952947 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | 0.49706054  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.7         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 18.5        |
# -----------------------------------------

# %%
# Read the monitor.csv file
monitor_file = f"{log_dir}/monitor.csv"
monitor_data = pd.read_csv(monitor_file, skiprows=1)  # Skip the first line (metadata)

# Check the structure of monitor_data
print(monitor_data.head())

# Extract episode numbers and rewards
training_reward = monitor_data[["r", "l"]].copy()  # 'r' is reward, 'l' is episode length
training_reward = training_reward.reset_index()
training_reward.rename(columns={"index": "Episode", "r": "Reward"}, inplace=True)

# Plot rewards vs. episodes
training_reward.hvplot(x="Episode", y="Reward", title="Training Reward over Episodes")
# Out:
#        r      l         t
# 0 -230.1  337.0  0.107146
# 1 -196.1  303.0  0.269331
# 2 -372.3  481.0  0.395936
# 3 -124.3  224.0  0.455451
# 4 -289.3  398.0  0.571148
# :Curve   [Episode]   (Reward)

# %%
# Load and test the model
model = PPO.load(model_save_path)
model
